# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import dateutil

# %%
df = pd.read_csv('Chicago_Crime_Detective.csv', low_memory = False, index_col = 0)

# %%
df
# Out:
#              ID            Date            LocationDescription  Arrest  \
# 0       8951354  12/31/12 23:15                         STREET   False
# 1       8951141  12/31/12 22:00                         STREET   False
# 2       8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3       8952223  12/31/12 22:00                         STREET   False
# 4       8951608  12/31/12 21:30                         STREET   False
# ...         ...             ...                            ...     ...
# 191636  1310068     1/1/01 0:05                         STREET   False
# 191637  1313404     1/1/01 0:01                         STREET   False
# 191638  1313442     1/1/01 0:01                         STREET   False
# 191639  1563324     1/1/01 0:01                         STREET   False
# 191640  1310463     1/1/01 0:01                         STREET   False
#
#         Domestic  Beat District CommunityArea  Year
# 0          False   623        6            69  2012
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191641 entries, 0 to 191640
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   191641 non-null  int64
#  1   Date                 191641 non-null  object
#  2   LocationDescription  191641 non-null  object
#  3   Arrest               191641 non-null  bool
#  4   Domestic             191641 non-null  bool
#  5   Beat                 191641 non-null  int64
#  6   District             148589 non-null  object
#  7   CommunityArea        167038 non-null  object
#  8   Year                 191641 non-null  int64
# dtypes: bool(2), int64(3), object(4)
# memory usage: 12.1+ MB

# %%
df['Date'] = df['Date'].apply(dateutil.parser.parse, dayfirst=True)

# %%
df['Date'].describe()
# Out:
# count                  191641
# unique                 131680
# top       2008-05-16 00:00:00
# freq                       11
# first     2001-01-01 00:01:00
# last      2012-12-31 23:15:00
# Name: Date, dtype: object

# %% [markdown]
# # Q1

# %%
df.median(axis = 0)
# Out:
# ID          4762956.0
# Arrest            0.0
# Domestic          0.0
# Beat           1121.0
# Year           2006.0
# dtype: float64

# %%
med_date = df[(df.ID == 4762956.0)]

# %%
med_date
# Out:
#             ID                Date LocationDescription  Arrest  Domestic  \
# 95628  4762956 2006-05-25 21:00:00              STREET   False     False
#
#        Beat District CommunityArea  Year
# 95628  1413     14.0            22  2006

# %%
df.describe()
# Out:
#                  ID           Beat           Year
# count  1.916410e+05  191641.000000  191641.000000
# mean   4.968629e+06    1258.810771    2006.134940
# std    2.342997e+06     702.530465       3.520285
# min    1.310022e+06     111.000000    2001.000000
# 25%    2.832144e+06     722.000000    2003.000000
# 50%    4.762956e+06    1121.000000    2006.000000
# 75%    7.201878e+06    1733.000000    2009.000000
# max    9.181151e+06    2535.000000    2012.000000

# %%
min_number = df[(df.Beat == 111)]

# %%
min_number
# Out:
#              ID                Date             LocationDescription  Arrest  \
# 4755    8784000 2012-08-31 17:11:00  PARKING LOT/GARAGE(NON.RESID.)   False
# 12821   8464412 2012-01-02 11:30:00  PARKING LOT/GARAGE(NON.RESID.)   False
# 13990   8424833 2012-03-01 13:30:00  PARKING LOT/GARAGE(NON.RESID.)   False
# 14471   8411327 2011-12-22 16:00:00                          STREET   False
# 14512   8410339 2011-12-21 16:30:00                          STREET   False
# ...         ...                 ...                             ...     ...
# 189747  1373667 2001-09-02 09:30:00                          STREET    True
# 189906  1366666 2001-05-02 16:15:00                           ALLEY   False
# 190957  1332627 2001-01-15 00:35:00                          STREET   False
# 191038  1331114 2001-01-13 09:00:00                          STREET   False
# 191070  1330701 2001-12-01 17:30:00                          STREET   False
#
#         Domestic  Beat District CommunityArea  Year
# ...

# %%
df.groupby('Year')['Date'].count()
# Out:
# Year
# 2001    20669
# 2002    18753
# 2003    16657
# 2004    16862
# 2005    16484
# 2006    16098
# 2007    14280
# 2008    14445
# 2009    12167
# 2010    15497
# 2011    15637
# 2012    14092
# Name: Date, dtype: int64

# %% [markdown]
# # Q2

# %%
df['month'] = df.Date.dt.month

# %%
dfx = df['month']
dfx
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 191636     1
# 191637     1
# 191638     1
# 191639     1
# 191640     1
# Name: month, Length: 191641, dtype: int64

# %%
month_count = dfx.value_counts()
month_count
# Out:
# 10    16977
# 7     16733
# 12    16417
# 1     16325
# 5     16298
# 8     16288
# 9     16009
# 3     15895
# 6     15894
# 11    15765
# 4     15086
# 2     13954
# Name: month, dtype: int64

# %% [markdown]
# # Q3

# %%
df['weekday'] = df.Date.dt.weekday

# %%
df['weekday'].value_counts()
# Out:
# 4    28545
# 5    27406
# 2    27387
# 0    27372
# 1    27141
# 3    27067
# 6    26723
# Name: weekday, dtype: int64

# %% [markdown]
# # Q4, Q7

# %%
df['Month'] = df.Date.dt.month

# %%
df
# Out:
#              ID                Date            LocationDescription  Arrest  \
# 0       8951354 2012-12-31 23:15:00                         STREET   False
# 1       8951141 2012-12-31 22:00:00                         STREET   False
# 2       8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3       8952223 2012-12-31 22:00:00                         STREET   False
# 4       8951608 2012-12-31 21:30:00                         STREET   False
# ...         ...                 ...                            ...     ...
# 191636  1310068 2001-01-01 00:05:00                         STREET   False
# 191637  1313404 2001-01-01 00:01:00                         STREET   False
# 191638  1313442 2001-01-01 00:01:00                         STREET   False
# 191639  1563324 2001-01-01 00:01:00                         STREET   False
# 191640  1310463 2001-01-01 00:01:00                         STREET   False
#
# ...

# %%
new4 = df.groupby(['month', 'Arrest']).count().reset_index()
new4.sort_values('ID', ascending=False)
# Out:
#     month  Arrest     ID   Date  LocationDescription  Domestic   Beat  \
# 18     10   False  15596  15596                15596     15596  15596
# 12      7   False  15379  15379                15379     15379  15379
# 22     12   False  15059  15059                15059     15059  15059
# 8       5   False  15045  15045                15045     15045  15045
# 14      8   False  15001  15001                15001     15001  15001
# 0       1   False  14973  14973                14973     14973  14973
# 16      9   False  14762  14762                14762     14762  14762
# 10      6   False  14646  14646                14646     14646  14646
# 4       3   False  14600  14600                14600     14600  14600
# 20     11   False  14500  14500                14500     14500  14500
# 6       4   False  13818  13818                13818     13818  13818
# 2       2   False  12726  12726                12726     12726  12726
# ...

# %% [markdown]
# # Q 5, Q6

# %%
df['Year'] = df.Date.dt.year

# %%
new_chart = df['Year'].value_counts()

# %%
new_chart
# Out:
# 2001    20669
# 2002    18753
# 2004    16862
# 2003    16657
# 2005    16484
# 2006    16098
# 2011    15637
# 2010    15497
# 2008    14445
# 2007    14280
# 2012    14092
# 2009    12167
# Name: Year, dtype: int64

# %% [markdown]
# # Q9 and Q10

# %%
new2 = df.groupby(['LocationDescription'])['ID'].count().reset_index()

# %%
new2.sort_values('ID', ascending=False).head(6)
# Out:
#                LocationDescription      ID
# 71                          STREET  156564
# 56  PARKING LOT/GARAGE(NON.RESID.)   14852
# 52                           OTHER    4573
# 9                            ALLEY    2308
# 39                     GAS STATION    2111
# 34          DRIVEWAY - RESIDENTIAL    1675

# %% [markdown]
# # Q8

# %%
new3 = df.groupby(['Year', 'Arrest']).count().reset_index()

# %%
new3.sort_values('ID', ascending=False)
# Out:
#     Year  Arrest     ID   Date  LocationDescription  Domestic   Beat  \
# 0   2001   False  18517  18517                18517     18517  18517
# 2   2002   False  16638  16638                16638     16638  16638
# 6   2004   False  15169  15169                15169     15169  15169
# 20  2011   False  15012  15012                15012     15012  15012
# 8   2005   False  14956  14956                14956     14956  14956
# 4   2003   False  14859  14859                14859     14859  14859
# 10  2006   False  14796  14796                14796     14796  14796
# 18  2010   False  14796  14796                14796     14796  14796
# 22  2012   False  13542  13542                13542     13542  13542
# 14  2008   False  13425  13425                13425     13425  13425
# 12  2007   False  13068  13068                13068     13068  13068
# 16  2009   False  11327  11327                11327     11327  11327
# 1   2001    True   2152   2152                 2152      2152   2152
# ...

# %% [markdown]
# # Q-11

# %%
top_movies = df.loc[df.LocationDescription =='GAS STATION', :]

# %%
top_movies.groupby(['LocationDescription','weekday']).count()
# Out:
#                               ID  Date  Arrest  Domestic  Beat  District  \
# LocationDescription weekday
# GAS STATION         0        287   287     287       287   287       207
#                     1        269   269     269       269   269       200
#                     2        294   294     294       294   294       222
#                     3        282   282     282       282   282       216
#                     4        316   316     316       316   316       239
#                     5        345   345     345       345   345       269
#                     6        318   318     318       318   318       231
#
#                              CommunityArea  Year  month  Month
# LocationDescription weekday
# GAS STATION         0                  240   287    287    287
#                     1                  236   269    269    269
#                     2                  252   294    294    294
#                     3                  249   282    282    282
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
new5 = df.groupby(['Year', 'Arrest']).count().reset_index()
new5.sort_values('ID', ascending=False)
# Out:
#     Year  Arrest     ID   Date  LocationDescription  Domestic   Beat  \
# 0   2001   False  18517  18517                18517     18517  18517
# 2   2002   False  16638  16638                16638     16638  16638
# 6   2004   False  15169  15169                15169     15169  15169
# 20  2011   False  15012  15012                15012     15012  15012
# 8   2005   False  14956  14956                14956     14956  14956
# 4   2003   False  14859  14859                14859     14859  14859
# 10  2006   False  14796  14796                14796     14796  14796
# 18  2010   False  14796  14796                14796     14796  14796
# 22  2012   False  13542  13542                13542     13542  13542
# 14  2008   False  13425  13425                13425     13425  13425
# 12  2007   False  13068  13068                13068     13068  13068
# 16  2009   False  11327  11327                11327     11327  11327
# 1   2001    True   2152   2152                 2152      2152   2152
# ...
